# %% [markdown]
# # How to Train YOLOv9 on a Custom Dataset
# ---
#
# [![Roboflow](https://raw.githubusercontent.com/roboflow-ai/notebooks/main/assets/badges/roboflow-blogpost.svg)](https://blog.roboflow.com/train-yolov9-model/)
# [![GitHub](https://badges.aleen42.com/src/github.svg)](https://github.com/WongKinYiu/yolov9)
# [![arXiv](https://img.shields.io/badge/arXiv-2402.13616-b31b1b.svg)](https://arxiv.org/pdf/2402.13616.pdf)
#
# <br>
#
# ![YOLOv9 Benchmark](https://storage.googleapis.com/com-roboflow-marketing/notebooks/examples/yolov9-benchmark.jpeg)
#
# **Figure 1.**  Comparisons of the real-time object detecors on MS
# COCO dataset. The GELAN and PGI-based object detection
# method surpassed all previous train-from-scratch methods in terms
# of object detection performance. Source: "YOLOv9: Learning What You Want to Learn Using Programmable Gradient Information"

# %% [markdown]
# ## Before you start
#
# Let's make sure that we have access to GPU. We can use `nvidia-smi` command to do that. In case of any problems navigate to `Edit` -> `Notebook settings` -> `Hardware accelerator`, set it to `GPU`, and then click `Save`.

# %%
# !nvidia-smi
# Out:
# Sun Feb 25 13:32:12 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# +-----------------------------------------+----------------------+----------------------+
#
# +---------------------------------------------------------------------------------------+
# | Processes:                                                                            |
# |  GPU   GI   CI        PID   Type   Process name                            GPU Memory |
# |        ID   ID                                                             Usage      |
# |=======================================================================================|
# |  No running processes found                                                           |
# +---------------------------------------------------------------------------------------+

# %% [markdown]
# **NOTE:** To make it easier for us to manage datasets, images and models we create a `HOME` constant.

# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /content

# %% [markdown]
# ## Clone and Install

# %% [markdown]
# **NOTE:** YOLOv9 is very new. At the moment, we recommend using a fork of the main repository. The `detect.py` script contains a bug that prevents inference. This bug is patched in the fork.

# %%
# !git clone https://github.com/SkalskiP/yolov9.git
# %cd yolov9
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'yolov9'...
# remote: Enumerating objects: 147, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (11/11), done.
# remote: Total 147 (delta 16), reused 14 (delta 14), pack-reused 122
# Receiving objects: 100% (147/147), 607.60 KiB | 2.36 MiB/s, done.
# Resolving deltas: 100% (58/58), done.
# /content/yolov9
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 195.4/195.4 kB 5.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 7.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 16.5 MB/s eta 0:00:00

# %% [markdown]
# **NOTE:** Let's install additional packages that will be useful later on.

# %%
# !pip install -q roboflow
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.2/70.2 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 11.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 6.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 9.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.7/86.7 kB 11.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.1 MB/s eta 0:00:00

# %% [markdown]
# ## Imports

# %%
import roboflow

from IPython.display import Image

# %% [markdown]
# ## Download model weights

# %% [markdown]
# **NOTE:** In the YOLOv9 paper, versions yolov9-s and yolov9-m are also mentioned, but the weights for these models are not yet available in the YOLOv9 repository.

# %%
# !mkdir -p {HOME}/weights

# %%
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/yolov9-e.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-c.pt
# !wget -P {HOME}/weights -q https://github.com/WongKinYiu/yolov9/releases/download/v0.1/gelan-e.pt

# %%
# !ls -la {HOME}/weights
# Out:
# total 402440
# drwxr-xr-x 2 root root      4096 Feb 25 13:33 .
# drwxr-xr-x 1 root root      4096 Feb 25 13:33 ..
# -rw-r--r-- 1 root root  51508261 Feb 18 12:36 gelan-c.pt
# -rw-r--r-- 1 root root 117203713 Feb 18 12:36 gelan-e.pt
# -rw-r--r-- 1 root root 103153312 Feb 18 12:36 yolov9-c.pt
# -rw-r--r-- 1 root root 140217688 Feb 18 12:36 yolov9-e.pt

# %% [markdown]
# ## Download example data

# %%
# !mkdir -p {HOME}/data

# %%
# !wget -P {HOME}/data -q https://media.roboflow.com/notebooks/examples/dog.jpeg

# %%
SOURCE_IMAGE_PATH = f"{HOME}/dog.jpeg"

# %% [markdown]
# **NOTE:** If you want to run inference using your own file as input, simply upload image to Google Colab and update `SOURCE_IMAGE_PATH` with the path leading to your file.

# %% [markdown]
# ## Detection with pre-trained COCO model

# %% [markdown]
# ### gelan-c

# %%
# !python detect.py --weights {HOME}/weights/gelan-c.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/weights/gelan-c.pt'], source=/content/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 467 layers, 25472640 parameters, 0 gradients, 102.8 GFLOPs
# image 1/1 /content/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 handbag, 159.9ms
# Speed: 0.4ms pre-process, 159.9ms inference, 681.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp

# %% [markdown]
# **NOTE:** By default, the results of each subsequent inference sessions are saved in `{HOME}/yolov9/runs/detect/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp/dog.jpeg", width=600)

# %% [markdown]
# ## yolov9-e

# %%
# !python detect.py --weights {HOME}/weights/yolov9-e.pt --conf 0.1 --source {HOME}/data/dog.jpeg --device 0
# Out:
# detect: weights=['/content/weights/yolov9-e.pt'], source=/content/data/dog.jpeg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 1119 layers, 69470144 parameters, 0 gradients, 244.0 GFLOPs
# image 1/1 /content/data/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 1 backpack, 1 handbag, 175.5ms
# Speed: 0.5ms pre-process, 175.5ms inference, 508.0ms NMS per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/exp2

# %%
Image(filename=f"{HOME}/yolov9/runs/detect/exp2/dog.jpeg", width=600)

# %% [markdown]
# ## Authenticate and Download the Dataset

# %% [markdown]
# **NOTE:** The dataset must be saved inside the `{HOME}/yolov9` directory, otherwise, the training will not succeed.

# %%
# %cd {HOME}/yolov9

roboflow.login()

rf = roboflow.Roboflow()

project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
dataset = project.version(1).download("yolov7")
# Out:
# /content/yolov9
# visit https://app.roboflow.com/auth-cli to get your authentication token.
# Paste the authentication token here: ··········
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in football-players-detection-1 to yolov7pytorch:: 100%|██████████| 148663/148663 [00:03<00:00, 40149.63it/s]
# Extracting Dataset Version Zip to football-players-detection-1 in yolov7pytorch:: 100%|██████████| 1338/1338 [00:00<00:00, 1527.01it/s]

# %% [markdown]
# ## Train Custom Model

# %%
# %cd {HOME}/yolov9

# !python train.py \
--batch 16 --epochs 20 --img 640 --device 0 --min-items 0 --close-mosaic 15 \
--data {dataset.location}/data.yaml \
--weights {HOME}/weights/gelan-c.pt \
--cfg models/detect/gelan-c.yaml \
--hyp hyp.scratch-high.yaml
# Out:
# /content/yolov9
# 2024-02-25 13:35:19.441949: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-25 13:35:19.442008: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-25 13:35:19.443386: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-25 13:35:20.472482: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# train: weights=/content/weights/gelan-c.pt, cfg=models/detect/gelan-c.yaml, data=/content/yolov9/football-players-detection-1/data.yaml, hyp=hyp.scratch-high.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=0, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, flat_cos_lr=False, fixed_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, min_items=0, close_mosaic=15, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, cls_pw=1.0, dfl=1.5, obj_pw=1.0, iou_t=0.2, anchor_t=5.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.9, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.15, copy_paste=0.3
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLO 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLO 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir runs/train', view at http://localhost:6006/
# Downloading https://ultralytics.com/assets/Arial.ttf to /root/.config/Ultralytics/Arial.ttf...
# 100% 755k/755k [00:00<00:00, 27.0MB/s]
# Overriding model.yaml nc=80 with nc=4
#
#                  from  n    params  module                                  arguments
#   0                -1  1      1856  models.common.Conv                      [3, 64, 3, 2]
#   1                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   2                -1  1    212864  models.common.RepNCSPELAN4              [128, 256, 128, 64, 1]
#   3                -1  1    164352  models.common.ADown                     [256, 256]
#   4                -1  1    847616  models.common.RepNCSPELAN4              [256, 512, 256, 128, 1]
#   5                -1  1    656384  models.common.ADown                     [512, 512]
#   6                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   7                -1  1    656384  models.common.ADown                     [512, 512]
#   8                -1  1   2857472  models.common.RepNCSPELAN4              [512, 512, 512, 256, 1]
#   9                -1  1    656896  models.common.SPPELAN                   [512, 512, 256]
#  10                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  11           [-1, 6]  1         0  models.common.Concat                    [1]
#  12                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  13                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  14           [-1, 4]  1         0  models.common.Concat                    [1]
#  15                -1  1    912640  models.common.RepNCSPELAN4              [1024, 256, 256, 128, 1]
#  16                -1  1    164352  models.common.ADown                     [256, 256]
#  17          [-1, 12]  1         0  models.common.Concat                    [1]
#  18                -1  1   2988544  models.common.RepNCSPELAN4              [768, 512, 512, 256, 1]
#  19                -1  1    656384  models.common.ADown                     [512, 512]
#  20           [-1, 9]  1         0  models.common.Concat                    [1]
#  21                -1  1   3119616  models.common.RepNCSPELAN4              [1024, 512, 512, 256, 1]
#  22      [15, 18, 21]  1   5493724  models.yolo.DDetect                     [4, [256, 512, 512]]
# gelan-c summary: 621 layers, 25440156 parameters, 25440140 gradients, 103.2 GFLOPs
#
# Transferred 931/937 items from /content/weights/gelan-c.pt
# AMP: checks passed ✅
# optimizer: SGD(lr=0.01) with parameter groups 154 weight(decay=0.0), 161 weight(decay=0.0005), 160 bias
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# train: Scanning /content/yolov9/football-players-detection-1/train/labels... 612 images, 0 backgrounds, 0 corrupt: 100% 612/612 [00:00<00:00, 878.32it/s]
# train: New cache created: /content/yolov9/football-players-detection-1/train/labels.cache
# val: Scanning /content/yolov9/football-players-detection-1/valid/labels... 38 images, 0 backgrounds, 0 corrupt: 100% 38/38 [00:00<00:00, 872.89it/s]
# val: New cache created: /content/yolov9/football-players-detection-1/valid/labels.cache
# Plotting labels to runs/train/exp/labels.jpg...
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/train/exp
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        0/19        14G      1.369      2.181     0.8687        226        640: 100% 39/39 [01:41<00:00,  2.59s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:03<00:00,  1.74s/it]
#                    all         38        905      0.537      0.252      0.267      0.126
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        1/19        14G      1.462      1.107     0.8441        125        640: 100% 39/39 [01:21<00:00,  2.10s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.97it/s]
#                    all         38        905       0.69      0.388      0.386      0.162
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        2/19        14G      1.635       1.11     0.8538        164        640: 100% 39/39 [01:24<00:00,  2.16s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.51it/s]
#                    all         38        905      0.657      0.409      0.387      0.108
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        3/19        14G      1.734      1.023     0.8706        150        640: 100% 39/39 [01:22<00:00,  2.12s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.32it/s]
#                    all         38        905      0.656      0.556      0.651       0.37
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        4/19        14G      1.596     0.9419     0.8564        158        640: 100% 39/39 [01:25<00:00,  2.18s/it]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.34it/s]
#                    all         38        905      0.886      0.562      0.644      0.358
# Closing dataloader mosaic
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        5/19        14G      1.316     0.7116     0.8517         92        640: 100% 39/39 [00:32<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.34it/s]
#                    all         38        905      0.743      0.549      0.647      0.369
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        6/19        14G      1.295     0.6242     0.8514         92        640: 100% 39/39 [00:33<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.53it/s]
#                    all         38        905      0.702      0.626      0.678      0.383
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        7/19        14G      1.187     0.5936     0.8364         94        640: 100% 39/39 [00:32<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.87it/s]
#                    all         38        905      0.787      0.656      0.712      0.362
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        8/19        14G      1.133     0.5642     0.8285         78        640: 100% 39/39 [00:32<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.82it/s]
#                    all         38        905      0.879      0.674      0.764      0.458
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#        9/19        14G      1.085     0.5208     0.8278         91        640: 100% 39/39 [00:33<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.84it/s]
#                    all         38        905      0.789      0.678      0.746      0.446
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       10/19        14G      1.046     0.5085     0.8215         89        640: 100% 39/39 [00:32<00:00,  1.21it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.57it/s]
#                    all         38        905      0.892      0.645      0.766      0.463
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       11/19        14G      1.022     0.4958     0.8154         63        640: 100% 39/39 [00:32<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.79it/s]
#                    all         38        905      0.878      0.686       0.77      0.456
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       12/19        14G     0.9732      0.471     0.8155         65        640: 100% 39/39 [00:32<00:00,  1.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.34it/s]
#                    all         38        905      0.863      0.672      0.751      0.472
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       13/19        14G     0.9236     0.4475     0.8131         70        640: 100% 39/39 [00:33<00:00,  1.18it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.69it/s]
#                    all         38        905      0.895      0.706      0.769       0.48
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       14/19        14G      0.939     0.4514     0.8079         87        640: 100% 39/39 [00:32<00:00,  1.20it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.63it/s]
#                    all         38        905      0.894      0.733      0.786       0.51
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       15/19        14G     0.9191     0.4431     0.8007         82        640: 100% 39/39 [00:34<00:00,  1.14it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.66it/s]
#                    all         38        905       0.87      0.698       0.78      0.527
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       16/19        14G     0.8721     0.4238      0.804         92        640: 100% 39/39 [00:32<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.36it/s]
#                    all         38        905       0.81      0.731      0.782      0.518
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       17/19        14G     0.8461     0.4096     0.8007         81        640: 100% 39/39 [00:33<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.58it/s]
#                    all         38        905      0.905      0.766      0.809      0.552
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       18/19        14G     0.8415     0.4077     0.7985         91        640: 100% 39/39 [00:33<00:00,  1.17it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.50it/s]
#                    all         38        905      0.897      0.751      0.804       0.56
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#       19/19        14G     0.8026     0.3824     0.7984         91        640: 100% 39/39 [00:32<00:00,  1.19it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:00<00:00,  2.30it/s]
#                    all         38        905      0.907       0.77      0.812      0.558
#
# 20 epochs completed in 0.277 hours.
# Optimizer stripped from runs/train/exp/weights/last.pt, saved as runs/train/exp/weights/last_striped.pt, 51.4MB
# Optimizer stripped from runs/train/exp/weights/best.pt, saved as runs/train/exp/weights/best_striped.pt, 51.4MB
#
# Validating runs/train/exp/weights/best.pt...
# Fusing layers...
# gelan-c summary: 467 layers, 25414044 parameters, 0 gradients, 102.5 GFLOPs
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 2/2 [00:01<00:00,  1.16it/s]
#                    all         38        905      0.897      0.751      0.804       0.56
#                   ball         38         35          1      0.226       0.37      0.121
#             goalkeeper         38         27      0.836      0.947      0.969      0.767
#                 player         38        754      0.948      0.947      0.983      0.772
#                referee         38         89      0.805      0.883      0.894      0.581
# Results saved to runs/train/exp

# %% [markdown]
# ## Examine Training Results

# %% [markdown]
# **NOTE:** By default, the results of each subsequent training sessions are saved in `{HOME}/yolov9/runs/train/`, in directories named `exp`, `exp2`, `exp3`, ... You can override this behavior by using the `--name` parameter.

# %%
# !ls {HOME}/yolov9/runs/train/exp/
# Out:
# confusion_matrix.png				    P_curve.png       train_batch2.jpg
# events.out.tfevents.1708868121.2919d443449a.2079.0  PR_curve.png      val_batch0_labels.jpg
# F1_curve.png					    R_curve.png       val_batch0_pred.jpg
# hyp.yaml					    results.csv       val_batch1_labels.jpg
# labels_correlogram.jpg				    results.png       val_batch1_pred.jpg
# labels.jpg					    train_batch0.jpg  weights
# opt.yaml					    train_batch1.jpg

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/results.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/confusion_matrix.png", width=1000)

# %%
Image(filename=f"{HOME}/yolov9/runs/train/exp/val_batch0_pred.jpg", width=1000)

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}/yolov9

# !python val.py \
--img 640 --batch 16 --conf 0.001 --iou 0.5 --device 0 \
--data {dataset.location}/data.yaml \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt
# Out:
# /content/yolov9
# val: data=/content/yolov9/football-players-detection-1/data.yaml, weights=['/content/yolov9/runs/train/exp/weights/best.pt'], batch_size=16, imgsz=640, conf_thres=0.001, iou_thres=0.5, max_det=300, task=val, device=0, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False, min_items=0
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25414044 parameters, 0 gradients, 102.5 GFLOPs
# val: Scanning /content/yolov9/football-players-detection-1/valid/labels.cache... 38 images, 0 backgrounds, 0 corrupt: 100% 38/38 [00:00<?, ?it/s]
#                  Class     Images  Instances          P          R      mAP50   mAP50-95: 100% 3/3 [00:05<00:00,  1.97s/it]
#                    all         38        905      0.908      0.754      0.807      0.568
#                   ball         38         35      0.984      0.229      0.372      0.109
#             goalkeeper         38         27      0.865      0.953      0.971      0.789
#                 player         38        754      0.964      0.947      0.986      0.788
#                referee         38         89      0.818      0.888      0.899      0.586
# Speed: 0.1ms pre-process, 49.6ms inference, 30.5ms NMS per image at shape (16, 3, 640, 640)
# Results saved to runs/val/exp

# %% [markdown]
# ## Inference with Custom Model

# %%
# !python detect.py \
--img 1280 --conf 0.1 --device 0 \
--weights {HOME}/yolov9/runs/train/exp/weights/best.pt \
--source {dataset.location}/valid/images
# Out:
# detect: weights=['/content/yolov9/runs/train/exp/weights/best.pt'], source=/content/yolov9/football-players-detection-1/valid/images, data=data/coco128.yaml, imgsz=[1280, 1280], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=0, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 1e33dbb Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# gelan-c summary: 467 layers, 25414044 parameters, 0 gradients, 102.5 GFLOPs
# image 1/38 /content/yolov9/football-players-detection-1/valid/images/08fd33_3_1_png.rf.6f25c835bf6d1828dcf584e5969b1f58.jpg: 736x1280 21 players, 2 referees, 100.6ms
# image 2/38 /content/yolov9/football-players-detection-1/valid/images/08fd33_3_3_png.rf.128b8280598b9931fdeeed42b5be4c51.jpg: 736x1280 1 ball, 21 players, 1 referee, 58.5ms
# image 3/38 /content/yolov9/football-players-detection-1/valid/images/08fd33_9_8_png.rf.cc61e7ba09940f4606e4464dd621fe2f.jpg: 736x1280 20 players, 2 referees, 59.2ms
# image 4/38 /content/yolov9/football-players-detection-1/valid/images/121364_7_9_png.rf.bd5ceb93233525ef03fac0eae292f5ed.jpg: 736x1280 19 players, 2 referees, 58.8ms
# image 5/38 /content/yolov9/football-players-detection-1/valid/images/121364_9_2_png.rf.400d952c966048709aa5b421889a4dba.jpg: 736x1280 1 ball, 21 players, 3 referees, 56.1ms
# image 6/38 /content/yolov9/football-players-detection-1/valid/images/121364_9_3_png.rf.175a041e339a6a4c918ae7f7141461aa.jpg: 736x1280 1 ball, 20 players, 3 referees, 56.4ms
# image 7/38 /content/yolov9/football-players-detection-1/valid/images/2e57b9_3_10_png.rf.f85ed097b3476e84600e0a9409959cf4.jpg: 736x1280 1 ball, 21 players, 3 referees, 55.8ms
# image 8/38 /content/yolov9/football-players-detection-1/valid/images/2e57b9_3_8_png.rf.6896c68ab1045f7595468d06c0021b79.jpg: 736x1280 2 balls, 21 players, 3 referees, 56.1ms
# image 9/38 /content/yolov9/football-players-detection-1/valid/images/2e57b9_9_1_png.rf.87b260e714b9f6af5288301e51014dc4.jpg: 736x1280 1 ball, 21 players, 3 referees, 56.3ms
# image 10/38 /content/yolov9/football-players-detection-1/valid/images/40cd38_7_7_png.rf.734097f181067cdf149fbd63249a51b2.jpg: 736x1280 1 ball, 1 goalkeeper, 22 players, 5 referees, 56.2ms
# image 11/38 /content/yolov9/football-players-detection-1/valid/images/42ba34_1_3_png.rf.e18c2b97d91dccbbdfe601c29b4817e3.jpg: 736x1280 2 balls, 1 goalkeeper, 20 players, 4 referees, 56.0ms
# image 12/38 /content/yolov9/football-players-detection-1/valid/images/42ba34_1_4_png.rf.0190fbc779b7f4320c25835a5d952de0.jpg: 736x1280 1 ball, 2 goalkeepers, 21 players, 3 referees, 56.5ms
# image 13/38 /content/yolov9/football-players-detection-1/valid/images/42ba34_3_2_png.rf.fd1addd604a4c47dea9dba52f7012203.jpg: 736x1280 21 players, 4 referees, 57.0ms
# image 14/38 /content/yolov9/football-players-detection-1/valid/images/42ba34_7_1_png.rf.f8b2cb5fd5d8f39278243a6bfe9279a1.jpg: 736x1280 1 ball, 21 players, 2 referees, 56.8ms
# image 15/38 /content/yolov9/football-players-detection-1/valid/images/4b770a_3_1_png.rf.4715dcbc4be0f14fbb5d8450fcff5bf0.jpg: 736x1280 1 ball, 1 goalkeeper, 21 players, 2 referees, 55.4ms
# image 16/38 /content/yolov9/football-players-detection-1/valid/images/4b770a_3_7_png.rf.0fe6dc6c1fd85518ff5456a914a7571d.jpg: 736x1280 22 players, 3 referees, 56.2ms
# image 17/38 /content/yolov9/football-players-detection-1/valid/images/4b770a_5_5_png.rf.32e220f7f4f090859fd2bb2ba0c5d8d1.jpg: 736x1280 21 players, 3 referees, 56.2ms
# image 18/38 /content/yolov9/football-players-detection-1/valid/images/538438_1_5_png.rf.927cf8101773ba75712dcee17a35e56b.jpg: 736x1280 2 balls, 19 players, 2 referees, 56.3ms
# image 19/38 /content/yolov9/football-players-detection-1/valid/images/538438_9_8_png.rf.f77a8d26e22089ac66e5c925a6d52d70.jpg: 736x1280 2 goalkeepers, 22 players, 4 referees, 56.7ms
# image 20/38 /content/yolov9/football-players-detection-1/valid/images/54745b_9_2_png.rf.459f3f85a7dab225b74601302e33d05b.jpg: 736x1280 2 balls, 1 goalkeeper, 22 players, 1 referee, 56.7ms
# image 21/38 /content/yolov9/football-players-detection-1/valid/images/54745b_9_4_png.rf.3227ab0fa5e4b28148cbb235e5fa8494.jpg: 736x1280 2 balls, 19 players, 1 referee, 58.7ms
# image 22/38 /content/yolov9/football-players-detection-1/valid/images/54745b_9_5_png.rf.277792543ff53b9e63dfe5ebd8b0141e.jpg: 736x1280 1 ball, 21 players, 2 referees, 58.0ms
# image 23/38 /content/yolov9/football-players-detection-1/valid/images/54745b_9_6_png.rf.9670b3ae25639828ce68a51f35ab0d95.jpg: 736x1280 21 players, 2 referees, 57.4ms
# image 24/38 /content/yolov9/football-players-detection-1/valid/images/573e61_1_10_png.rf.a01a3d439e964eb4342eb9e7d49295e6.jpg: 736x1280 2 balls, 19 players, 2 referees, 58.3ms
# image 25/38 /content/yolov9/football-players-detection-1/valid/images/744b27_1_6_png.rf.a47d969e663ab6a912c9ddcb7ac9ada4.jpg: 736x1280 1 ball, 20 players, 2 referees, 58.2ms
# image 26/38 /content/yolov9/football-players-detection-1/valid/images/744b27_1_7_png.rf.b2d05a9295c0da84bb0f7107fa0b44f5.jpg: 736x1280 20 players, 2 referees, 58.3ms
# image 27/38 /content/yolov9/football-players-detection-1/valid/images/744b27_3_7_png.rf.8611933fe3c87a1f7cdc044eb6076239.jpg: 736x1280 1 goalkeeper, 21 players, 2 referees, 56.5ms
# image 28/38 /content/yolov9/football-players-detection-1/valid/images/744b27_7_1_png.rf.f8de7a6218a47e85554c874fb48dbb72.jpg: 736x1280 1 ball, 22 players, 3 referees, 56.0ms
# image 29/38 /content/yolov9/football-players-detection-1/valid/images/744b27_7_5_png.rf.0d0d78b8bd87f5c6e4fff3f07aff5264.jpg: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 55.9ms
# image 30/38 /content/yolov9/football-players-detection-1/valid/images/744b27_7_6_png.rf.1bcd345f6691254eddeea6e9cb8425a4.jpg: 736x1280 2 balls, 22 players, 2 referees, 55.3ms
# image 31/38 /content/yolov9/football-players-detection-1/valid/images/744b27_7_7_png.rf.962e610b06248637fd063e49893216a8.jpg: 736x1280 1 ball, 1 goalkeeper, 22 players, 3 referees, 55.7ms
# image 32/38 /content/yolov9/football-players-detection-1/valid/images/744b27_9_8_png.rf.68e5d3f2de2384cd05cdb3f5edbd051b.jpg: 736x1280 1 ball, 20 players, 2 referees, 56.4ms
# image 33/38 /content/yolov9/football-players-detection-1/valid/images/798b45_1_1_png.rf.8439a1c181599a0556904a92fd89bd81.jpg: 736x1280 21 players, 3 referees, 56.2ms
# image 34/38 /content/yolov9/football-players-detection-1/valid/images/798b45_1_2_png.rf.16fbff81b9da39745fd50739c7f50b60.jpg: 736x1280 1 goalkeeper, 20 players, 2 referees, 56.3ms
# image 35/38 /content/yolov9/football-players-detection-1/valid/images/798b45_7_4_png.rf.7e95236908fb69555ee34e25ab14b662.jpg: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 56.5ms
# image 36/38 /content/yolov9/football-players-detection-1/valid/images/798b45_7_5_png.rf.5e0e5e1e6456340e3fb21908d6e028d9.jpg: 736x1280 1 goalkeeper, 20 players, 2 referees, 55.2ms
# image 37/38 /content/yolov9/football-players-detection-1/valid/images/798b45_9_8_png.rf.04032c3799e0f6e13589c90ba3c4bdeb.jpg: 736x1280 1 ball, 1 goalkeeper, 20 players, 2 referees, 56.5ms
# image 38/38 /content/yolov9/football-players-detection-1/valid/images/a9f16c_8_10_png.rf.9835e230bebd2303d07d0147fe441dfa.jpg: 736x1280 2 balls, 3 goalkeepers, 21 players, 3 referees, 56.4ms
# Speed: 1.1ms pre-process, 57.9ms inference, 14.0ms NMS per image at shape (1, 3, 1280, 1280)
# Results saved to runs/detect/exp4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/yolov9/runs/detect/exp4/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")
